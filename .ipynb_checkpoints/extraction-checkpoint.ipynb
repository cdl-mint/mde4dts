# %%
import pandas as pd

# %% [markdown]
# # Extraction based on Title + Abstract

# %%
titles_all = pd.read_csv("./data/titles_all.csv", sep=";", header=None)
#titles_all  = titles_all[titles_all[titles_all[0]].notnull().all(1)]
titles_all = titles_all.drop_duplicates()
extracted_title_abstract = pd.read_csv("./data/titles_metadata_after_abstract.csv", sep=";")

# %%
print(len(titles_all))
print(len(extracted_title_abstract))
# Out:
# 112
# 77

# %% [markdown]
# # Extraction based on Paper contents

# %%
#title_abstract = pd.read_csv("./data/extraction_titleabstract_merged.csv", sep=";")
paper_daniel = pd.read_csv("./data/extraction_paper_daniel.csv", sep=";")
paper_daniel = paper_daniel[paper_daniel[['Title']].notnull().all(1)]
paper_daniel = paper_daniel.drop_duplicates(subset="Title")
paper_daniel["Reason"] = paper_daniel["Reason"].fillna("OK")
paper_jerome = pd.read_csv("./data/extraction_paper_jerome.csv", sep=";")
paper_jerome = paper_jerome[paper_jerome[['Title']].notnull().all(1)]
paper_jerome = paper_jerome.drop_duplicates(subset="Title")
paper_jerome["Reason"] = paper_jerome["Reason"].fillna("OK")
paper_jingxi = pd.read_csv("./data/extraction_paper_jingxi.csv", sep=";")
paper_jingxi  = paper_jingxi[paper_jingxi[['Title']].notnull().all(1)]
paper_jingxi = paper_jingxi.drop_duplicates(subset="Title")
paper_jingxi["Reason"] = paper_jingxi["Reason"].fillna("OK")
paper_ann = pd.read_csv("./data/extraction_paper_ann.csv", sep=";")
paper_ann = paper_ann[paper_ann[['Title']].notnull().all(1)]
paper_ann = paper_ann.drop_duplicates(subset="Title")
paper_ann["Reason"] = paper_ann["Reason"].fillna("OK")

# %%
paper_merged = paper_jerome.merge(paper_daniel, how='outer', on='Title')
paper_merged = paper_merged.merge(paper_jingxi, how='outer', on='Title')
paper_merged = paper_merged.rename(columns={"Reason_x": "Reason Jerome", "Reason_y": "Reason Daniel", "Reason": "Reason Jingxi"})
paper_merged = paper_merged.merge(paper_ann, how='outer', on='Title')
paper_merged = paper_merged.rename(columns={"Reason": "Reason Ann"})
paper_merged
# Out:
#                                                 Title  \
# 0   Model-Driven Digital Twin Construction: Synthe...
# 1      Measuring the Fidelity of Digital Twin Systems
# 2   Digital Twin as Risk-Free Experimentation Aid ...
# 3   Using Trace Alignments for Measuring the Simil...
# 4   Towards a Digital Twin for Cyber-Physical Prod...
# ..                                                ...
# 72  Enabling Semantic Interoperability of Asset Ad...
# 73  Challenges and Possible Approaches for Sustain...
# 74  Coordination and Explanation of Reconfiguratio...
# 75  Case Study on Automated and Continuous Reliabi...
# 76  Integration of SysML Models in a 3D Environmen...
#
#                Reason Jerome             Reason Daniel  \
# 0                         OK                        OK
# 1   Challenge/Position Paper  Challenge/Position Paper
# 2      No MDE technique used     No MDE technique used
# 3              No Model used                        OK
# 4                         OK     No MDE technique used
# ..                       ...                       ...
# 72                       NaN                       NaN
# 73                       NaN                       NaN
# 74                       NaN                       NaN
# 75                       NaN                       NaN
# 76                       NaN                       NaN
#
#                Reason Jingxi                Reason Ann
# 0                         OK                        OK
# 1                        NaN  Challenge/Position Paper
# 2                        NaN     No MDE technique used
# 3                        NaN             No Model used
# 4                        NaN                        OK
# ..                       ...                       ...
# 72                        OK                        OK
# 73  Challenge/Position Paper  Challenge/Position Paper
# 74  Challenge/Position Paper  Challenge/Position Paper
# 75  Challenge/Position Paper                        OK
# 76                        OK                        OK
#
# [77 rows x 5 columns]

# %%
paper_merged.to_csv("./data/extraction_merged.csv", sep=";")

# %%
paper_cleaned = pd.read_csv("./data/extraction_merged.csv", sep=";")

# %%
paper_cleaned.head()
paper_cleaned['Reason_Consolidated'].value_counts()
paper_ok = paper_cleaned[paper_cleaned['Reason_Consolidated'] == 'OK']
paper_ok = paper_ok["Title"]

# %% [markdown]
# # Collect extracted data for remaining papers

# %%
data_jingxi = pd.read_csv("./data/data_jingxi.csv", sep=";", encoding="latin-1")
data_jingxi = data_jingxi[data_jingxi[['Title']].notnull().all(1)]
data_jingxi["Reviewer"] = "Jingxi"
data_daniel = pd.read_csv("./data/data_daniel.csv", sep=";", encoding="latin-1")
data_daniel = data_daniel[data_daniel[['Title']].notnull().all(1)]
data_daniel["Reviewer"] = "Daniel"
data_jerome = pd.read_csv("./data/data_jerome.csv", sep=";", encoding="latin-1")
data_jerome = data_jerome[data_jerome[['Title']].notnull().all(1)]
data_jerome["Reviewer"] = "Jerome"
data_ann = pd.read_csv("./data/data_ann.csv", sep=";", encoding="latin-1")
data_ann = data_ann[data_ann[['Title']].notnull().all(1)]
data_ann["Reviewer"] = "Ann"

# %%
#data_daniel_jerome_ann = set(data_jerome["Title"]).intersection(set(data_daniel["Title"]))
data_daniel_jerome_ann = data_daniel_jerome_ann.intersection(set(data_ann["Title"]))
data_daniel
#data_daniel_jerome_ann = pd.Series(list(data_daniel_jerome_ann))                                                              
                                                                #data_daniel_jerome_ann = pd.concat([data_daniel_jerome_ann, data_ann["Title"]], ignore_index=True)
#data_daniel["Title"].merge(data_jerome["Title"], how='inner', on='Title')
#data_daniel_jerome_ann = data_daniel_jerome_ann.merge(data_ann, how='inner', on='Title')
# Out:
#                                                 Title  \
# 0   Model-Driven Digital Twin Construction: Synthe...
# 1   Model-Driven Digital Twin Construction: Synthe...
# 2   Model-Driven Digital Twin Construction: Synthe...
# 3   Model-Driven Digital Twin Construction: Synthe...
# 4   Model-Driven Digital Twin Construction: Synthe...
# 5   A Novel Methodology to Construct Digital Twin ...
# 6   Understanding and Improving Model-Driven IoT S...
# 7   Understanding and Improving Model-Driven IoT S...
# 8   CPSAML: A Language and Code Generation Framewo...
# 9   CPSAML: A Language and Code Generation Framewo...
# 10  On the Engineering of IoT-Intensive Digital Tw...
# 11  On the Engineering of IoT-Intensive Digital Tw...
# 12  A Flexible and Modular Architecture for Edge D...
# 13  Enabling Semantic Interoperability of Asset Ad...
# 14  Challenges and Possible Approaches for Sustain...
# 15  Coordination and Explanation of Reconfiguratio...
# 16  Case Study on Automated and Continuous Reliabi...
# 17  Integration of SysML Models in a 3D Environmen...
# 18  Semantic digital twins for organizational deve...
# 19  A pattern catalog for augmenting Digital Twin ...
# 20  Ensuring consistency in scalable-detail models...
# 21  The OMiLAB Digital Innovation environment: Agi...
# 22  Digital twin enhanced human-machine interactio...
# 23  A Digital Twin Model-Driven Architecture for C...
# 24  Model-driven engineering city spaces via bidir...
# 25  A New 5S Radar Structure Design Model Driven b...
# 26  Towards Reactive Planning with Digital Twins a...
# 27  Model-Driven Engineering in Digital Thread Pla...
# 28  Performance Evaluation: Model-Driven or Proble...
# 29  Towards Development Platforms for Digital Twin...
# 30  Applying a Healthcare Web of Things Framework ...
# 31  Towards a Model-Driven Architecture for Intera...
# 32  Dynamic design method of digital twin process ...
# 33  The Research of Aero-engine Digital Twin Model...
# 34  Generative and Model-driven SDK development fo...
# 35  Towards a Reference Architecture for Leveragin...
# 36  Digital Twin Operational Platform for Connecti...
# 37  Data- and model-driven digital twins for desig...
# 38  A software engineering point of view on digita...
# 39              Process Prediction with Digital Twins
# 40  AML4DT: A Model-Driven Framework for Developin...
# 41  AML4DT: A Model-Driven Framework for Developin...
# 42  Twin Process Model Driven Machining Quality Op...
# 43  Multisource Model-Driven Digital Twin System o...
# 44  Semantic Interoperability of Digital Twins: On...
# 45  Semantic Interoperability of Digital Twins: On...
# 46  Semantic Interoperability of Digital Twins: On...
# 47  Semantic Interoperability of Digital Twins: On...
# 48  A Lightweight Model-driven MES Simulation Fram...
# 49  Digital Twin of an Electrical Motor Based on E...
# 50  Closed-Loop Systems Engineering (CLOSE): Integ...
# 51  Research on Modeling Method of System Reliabil...
# 52  Improved Electric Vehicle Digital Twin Perform...
# 53  Workshop Management and Control System Based o...
# 54  Using UML and OCL Models to Realize High-Level...
# 55  Using UML and OCL Models to Realize High-Level...
# 56  Interface Development for Digital Twin of an E...
# 57  A Model-Driven Approach for Situational Intell...
# 58  Knowledge driven rapid development of white bo...
#
#                       Reason  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12             No Model used
# 13                       NaN
# 14  Challenge/Position Paper
# 15  Challenge/Position Paper
# 16  Challenge/Position Paper
# 17                       NaN
# 18  Challenge/Position Paper
# 19                       NaN
# 20     No MDE technique used
# 21             Not Available
# 22  Challenge/Position Paper
# 23     No MDE technique used
# 24                       NaN
# 25     No MDE technique used
# 26                       NaN
# 27  Challenge/Position Paper
# 28     No MDE technique used
# 29  Challenge/Position Paper
# 30  Challenge/Position Paper
# 31                       NaN
# 32     No MDE technique used
# 33     No MDE technique used
# 34                       NaN
# 35             No Model used
# 36             No Model used
# 37     No MDE technique used
# 38  Challenge/Position Paper
# 39  Challenge/Position Paper
# 40                       NaN
# 41                       NaN
# 42                       NaN
# 43     No MDE technique used
# 44                       NaN
# 45                       NaN
# 46                       NaN
# 47                       NaN
# 48                       NaN
# 49                       NaN
# 50     No MDE technique used
# 51     No MDE technique used
# 52     No MDE technique used
# 53     No MDE technique used
# 54                       NaN
# 55                       NaN
# 56     No MDE technique used
# 57     No MDE technique used
# 58                       NaN
#
#                                         DT Definition  \
# 0   A digital twin (DT) of a system consists of a ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   A Digital Twin (DT) is a virtual representatio...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  DTs are complex entities whose design, develop...
# 11  DTs are complex entities whose design, develop...
# 12  Digital Twin (DT) originally introduced betwee...
# 13  The purpose of the digital twin technology [3]...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  A Digital Twin is\na digital 3D - CAD replica ...
# 18  A DT is, in its common definition, the virtual...
# 19  DTs are software systems comprising data, mode...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  In the\nrealm of smart cities, a digital twin ...
# 25  , this paper considers that Digital\nTwin is a...
# 26  As mentioned before, DTs enable a bi-direction...
# 27                                                NaN
# 28  a digital twin is a virtual (digital) represen...
# 29  Digital Twins are software systems comprising ...
# 30                                                NaN
# 31  DTs are often described as a digital duplicate...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  The digital twin is\ndefined as an extended vi...
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42  Digital twin is an efficient method to realize...
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49  The concept of Digital Twin (DT) is creating a...
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54  A Digital Twin (DT) is a comprehensive digital...
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
#
#                                     modeling language model type  notation  \
# 0                                                  CD  structure       NaN
# 1                                            MontiArc  structure       NaN
# 2                                               UML/P  structure       NaN
# 3                                                 OCL  structure       NaN
# 4                                            MontiGem  structure       NaN
# 5                                                 NaN  structure       NaN
# 6                                            MontiArc  structure       NaN
# 7                                     MontiThings ADL  structure       NaN
# 8                                             SYSML 2  structure       NaN
# 9                                                 ROS  structure       NaN
# 10                                            GEMINIS  structure       NaN
# 11                                            GEMINIS   behavior       NaN
# 12                                                NaN        NaN       NaN
# 13                                MaRCO, OML, AAS-UML  structure       NaN
# 14                                                NaN        NaN       NaN
# 15                                                NaN        NaN       NaN
# 16                                                NaN        NaN       NaN
# 17                                              SYSML  structure       NaN
# 18                                                NaN        NaN       NaN
# 19                                                NaN        NaN       NaN
# 20                                                NaN        NaN       NaN
# 21                                                NaN        NaN       NaN
# 22                                                NaN        NaN       NaN
# 23                                                NaN        NaN       NaN
# 24               CityGML/Application Domain Extension  structure       NaN
# 25                                                NaN        NaN       NaN
# 26                                       EMF, Henshin  structure       NaN
# 27                                                NaN        NaN       NaN
# 28                                                NaN        NaN       NaN
# 29                              CDs; data models; OCL  structure       NaN
# 30                                                NaN        NaN       NaN
# 31  MontiArc, MontiGem, CD, OCL, tagging, GUI-DSL ...  structure       NaN
# 32                                                NaN        NaN       NaN
# 33                                                NaN        NaN       NaN
# 34                                      AAS metamodel  structure       NaN
# 35                                                NaN        NaN       NaN
# 36                                                NaN        NaN       NaN
# 37                                                NaN        NaN       NaN
# 38                                                NaN        NaN       NaN
# 39                                                OCL  structure       NaN
# 40                           CAEX, AML, AML-MM, DT-MM  structure       NaN
# 41                                                ATL  structure       NaN
# 42                                                NaN  structure       NaN
# 43                                                NaN        NaN       NaN
# 44                                                OWL  structure       NaN
# 45                                                OML  structure       NaN
# 46                                                UML  structure       NaN
# 47                                                AAS  structure       NaN
# 48                                                XML  structure       NaN
# 49                                    Unity 3D, ROS,    behavior       NaN
# 50                                                NaN        NaN       NaN
# 51                                                NaN        NaN       NaN
# 52                                                NaN        NaN       NaN
# 53                                                NaN        NaN       NaN
# 54                                            UML/OCL  structure       NaN
# 55                                               SOIL   behavior       NaN
# 56                                                NaN        NaN       NaN
# 57                                                NaN        NaN       NaN
# 58  Control Natural Language (CNL); Meta-Model; M&...  structure       NaN
#
#                     MDE technique       direction  \
# 0   Model to Model Transformation  unidirectional
# 1                 code generation             NaN
# 2                             NaN             NaN
# 3                             NaN             NaN
# 4                             NaN             NaN
# 5   Model to Model Transformation  unidirectional
# 6   Model to Model Transformation  unidirectional
# 7   Model to Model Transformation  unidirectional
# 8   Model to Model Transformation  unidirectional
# 9                             NaN             NaN
# 10           model interpretation             NaN
# 11           model interpretation             NaN
# 12                            NaN             NaN
# 13  Model to Model Transformation  unidirectional
# 14                            NaN             NaN
# 15                            NaN             NaN
# 16                            NaN             NaN
# 17  Model to Model Transformation  unidirectional
# 18                            NaN             NaN
# 19                            NaN             NaN
# 20                            NaN             NaN
# 21                            NaN             NaN
# 22                            NaN             NaN
# 23                            NaN             NaN
# 24  Model to Model Transformation   bidirectional
# 25                            NaN             NaN
# 26           model interpretation             NaN
# 27                            NaN             NaN
# 28                            NaN             NaN
# 29  Model to Model Transformation  unidirectional
# 30                            NaN             NaN
# 31                code generation             NaN
# 32                            NaN             NaN
# 33                            NaN             NaN
# 34                code generation             NaN
# 35                            NaN             NaN
# 36                            NaN             NaN
# 37                            NaN             NaN
# 38                            NaN             NaN
# 39                code generation             NaN
# 40  Model to Model Transformation             NaN
# 41           model interpretation             NaN
# 42           model interpretation             NaN
# 43                            NaN             NaN
# 44  Model to Model Transformation             NaN
# 45  Model to Model Transformation             NaN
# 46           model interpretation             NaN
# 47           model interpretation             NaN
# 48                            NaN             NaN
# 49           model interpretation             NaN
# 50                            NaN             NaN
# 51                            NaN             NaN
# 52                            NaN             NaN
# 53                            NaN             NaN
# 54           model interpretation             NaN
# 55                            NaN             NaN
# 56                            NaN             NaN
# 57                            NaN             NaN
# 58  Model to Model Transformation             NaN
#
#                                                source  \
# 0                                         CD/MontiArc
# 1                                         CD/MontiArc
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                         Fault Trees
# 6                                                 ADL
# 7                                                 ADL
# 8                                             SYSML 2
# 9                                                 NaN
# 10      metamodels? structural graph-based DTP models
# 11                       DTP and DTI behaviour models
# 12                                                NaN
# 13                                                OML
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                              SYSML
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                            CityGML
# 25                                                NaN
# 26                   Meta-model, Transformation Rules
# 27                                                NaN
# 28                                                NaN
# 29                                     DT Models: CDs
# 30                                                NaN
# 31                   CD, OCL, tagging, GUI-DSL models
# 32                                                NaN
# 33                                                NaN
# 34  data structures, operations,contracts, de/seri...
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39  CD, OCL, Tagging, Data models, GUI models, Pro...
# 40                                                AML
# 41                                                 DT
# 42                                 Twin Process Model
# 43                                                NaN
# 44                                                OWL
# 45                                                OML
# 46                                                UML
# 47                                                AAS
# 48                                         XML as PFA
# 49                              physical measurements
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                USE
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58  Semantic Application Design Language(SADL) as ...
#
#                                                target  \
# 0                                            CPS/DTIS
# 1                                            CPS/DTIS
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                        Operationds-Dedicated Models
# 6                                                 CPS
# 7                                                 CPS
# 8         Xtend, Java, Typescript, Python, Dockerfile
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                          AAS Model
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                   Unity GameObject
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                topologial 3D model
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                  digital twin code
# 30                                                NaN
# 31                                                 UI
# 32                                                NaN
# 33                                                NaN
# 34                                                GPL
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                GPL
# 40                                                 DT
# 41                                            AzureDT
# 42                                            NC Code
# 43                                                NaN
# 44                                                OML
# 45                                                UML
# 46                                                AAS
# 47                                       OWL Ontology
# 48                                                  ?
# 49                                    DT Model Update
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                 DL
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58  control systems model then finiteState Mmachin...
#
#                                               purpose  \
# 0          Integration of CPS and Information Systems
# 1          Integration of CPS and Information Systems
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6          Integration of CPS and Information Systems
# 7          Integration of CPS and Information Systems
# 8          Integration of CPS and Information Systems
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                    3D Visualization of SYSML model
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  mitigate runtime deviations\ncompared to naive...
# 27                                                NaN
# 28                                                NaN
# 29  facilitates researchers and practitioners in m...
# 30                                                NaN
# 31  . This facilitates\ncreating, deploying, and m...
# 32                                                NaN
# 33                                                NaN
# 34                                                SDK
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                      generative DT
# 40                                                NaN
# 41                                                NaN
# 42                                           Optimize
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49  provide a brand-new approach\nfor measurement ...
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
#
#                                                domain system lifecycle phase  \
# 0                   J  Information and Communication                 Design
# 1                   J  Information and Communication              Implement
# 2                   J  Information and Communication                Operate
# 3                   J  Information and Communication                Operate
# 4                   J  Information and Communication                Operate
# 5   M  Professional, Scientific and Technical Act...                Operate
# 6                   J  Information and Communication                 Design
# 7                   J  Information and Communication              Implement
# 8                   J  Information and Communication                 Design
# 9                                                 NaN                    NaN
# 10                                                NaN                    NaN
# 11                                                NaN                 Design
# 12                                                NaN                    NaN
# 13                  J  Information and Communication                 Design
# 14                                                NaN                    NaN
# 15                                                NaN                    NaN
# 16                                                NaN                    NaN
# 17                  J  Information and Communication                 Design
# 18                                                NaN                    NaN
# 19                                                NaN                    NaN
# 20                                                NaN                    NaN
# 21                                                NaN                    NaN
# 22                                                NaN                    NaN
# 23                                                NaN                    NaN
# 24                                   F  Construction                   Plan
# 25                                                NaN                    NaN
# 26                  J  Information and Communication                Operate
# 27                                                NaN                    NaN
# 28                                                NaN                    NaN
# 29                  J  Information and Communication                 Design
# 30                                                NaN                    NaN
# 31                  J  Information and Communication                Operate
# 32                                                NaN                    NaN
# 33                                                NaN                    NaN
# 34                  J  Information and Communication              Implement
# 35                                                NaN                    NaN
# 36                                                NaN                    NaN
# 37                                                NaN                    NaN
# 38                                                NaN                    NaN
# 39                  J  Information and Communication              Implement
# 40                  J  Information and Communication              Implement
# 41  N  Administrative and Support Service Activities              Implement
# 42                                   F  Construction                Operate
# 43                                                NaN                    NaN
# 44                                  C  Manufacturing                 Design
# 45                                  C  Manufacturing                 Design
# 46                                  C  Manufacturing                 Design
# 47                                  C  Manufacturing                 Design
# 48                  J  Information and Communication                 Design
# 49                     H  Transportation and Storage                Operate
# 50                                                NaN                    NaN
# 51                                                NaN                    NaN
# 52                                                NaN                    NaN
# 53                                                NaN                    NaN
# 54                     H  Transportation and Storage                Operate
# 55                                                NaN                    NaN
# 56                                                NaN                    NaN
# 57                                                NaN                    NaN
# 58  D  Electricity, Gas, Steam and Air Conditioni...                Operate
#
#                                       twinning target twin lifecycle phase  \
# 0   Individual Systems, such as automated cars (At...          As-Designed
# 1   Individual Systems, such as automated cars (At...          As-Designed
# 2   Individual Systems, such as automated cars (At...          As-Operated
# 3   Individual Systems, such as automated cars (At...          As-Operated
# 4   Individual Systems, such as automated cars (At...          As-Operated
# 5   Individual Systems, such as automated cars (At...          As-Designed
# 6   Individual Systems, such as automated cars (At...          As-Designed
# 7   Individual Systems, such as automated cars (At...          As-Designed
# 8   Individual Systems, such as automated cars (At...          As-Designed
# 9                                                 NaN                  NaN
# 10                                                NaN                  NaN
# 11  Individual Systems, such as automated cars (At...          As-Designed
# 12                                                NaN                  NaN
# 13  Individual Systems, such as automated cars (At...          As-Designed
# 14                                                NaN                  NaN
# 15                                                NaN                  NaN
# 16                                                NaN                  NaN
# 17  Individual Systems, such as automated cars (At...                  NaN
# 18                                                NaN                  NaN
# 19                                                NaN                  NaN
# 20                                                NaN                  NaN
# 21                                                NaN                  NaN
# 22                                                NaN                  NaN
# 23                                                NaN                  NaN
# 24  Processes, e.g., business processes (Rambow-Ho...          As-Designed
# 25                                                NaN                  NaN
# 26  Individual Systems, such as automated cars (At...          As-Operated
# 27                                                NaN                  NaN
# 28                                                NaN                  NaN
# 29  Individual Systems, such as automated cars (At...          As-Designed
# 30                                                NaN                  NaN
# 31  Individual Systems, such as automated cars (At...          As-Operated
# 32                                                NaN                  NaN
# 33                                                NaN                  NaN
# 34  Individual Systems, such as automated cars (At...          As-Designed
# 35                                                NaN                  NaN
# 36                                                NaN                  NaN
# 37                                                NaN                  NaN
# 38                                                NaN                  NaN
# 39  Individual Systems, such as automated cars (At...          As-Designed
# 40  Individual Systems, such as automated cars (At...          As-Designed
# 41  Individual Systems, such as automated cars (At...          As-Operated
# 42  Individual Systems, such as automated cars (At...          As-Operated
# 43                                                NaN                  NaN
# 44  Systems of Systems, such as complete factories...          As-Designed
# 45  Systems of Systems, such as complete factories...          As-Designed
# 46  Systems of Systems, such as complete factories...          As-Designed
# 47  Systems of Systems, such as complete factories...          As-Designed
# 48  Individual Systems, such as automated cars (At...          As-Designed
# 49  Individual Systems, such as automated cars (At...          As-Operated
# 50                                                NaN                  NaN
# 51                                                NaN                  NaN
# 52                                                NaN                  NaN
# 53                                                NaN                  NaN
# 54  Individual Systems, such as automated cars (At...          As-Designed
# 55                                                NaN                  NaN
# 56                                                NaN                  NaN
# 57                                                NaN                  NaN
# 58  Systems of Systems, such as complete factories...          As-Designed
#
#             purpose /expected benefit of using models  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  To address the complexity of systems, it is ne...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  guarantees that synchronization between models...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  This facilitates\ncreating, deploying, and mon...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39  overcome the challenges\nof bi-directional syn...
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
#
#                                       open challenges  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  However, more research and development are nee...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  investigate pluggable custom application polic...
# 25                                                NaN
# 26  additional scenarios have to be explored to fu...
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  we still need to evaluate our reference archit...
# 32                                                NaN
# 33                                                NaN
# 34                         further GPL, build parsers
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42  could supply abilities including self-updating...
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
#
#                         TEchnological REadiness Level  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   1-3: die Technologie gibt's, evtl. am Toy Exam...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                     4-5: das Ding läuft "im Labor"
# 25                                                NaN
# 26  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 27                                                NaN
# 28                                                NaN
# 29  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 30                                                NaN
# 31  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 32                                                NaN
# 33                                                NaN
# 34  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 40  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 41  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 42  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 43                                                NaN
# 44  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 45  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 46  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 47  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 48  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 49  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54  1-3: die Technologie gibt's, evtl. am Toy Exam...
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58  1-3: die Technologie gibt's, evtl. am Toy Exam...
#
#                                                 notes Reviewer
# 0                                                 NaN   Daniel
# 1                                                 NaN   Daniel
# 2                                                 NaN   Daniel
# 3                                                 NaN   Daniel
# 4                                                 NaN   Daniel
# 5                                                 NaN   Daniel
# 6                                                 NaN   Daniel
# 7                                                 NaN   Daniel
# 8                                                 NaN   Daniel
# 9                                                 NaN   Daniel
# 10                                                NaN   Daniel
# 11                                                NaN   Daniel
# 12         DT Concept but no MDE directly extractable   Daniel
# 13                                                NaN   Daniel
# 14                                                NaN   Daniel
# 15                                                NaN   Daniel
# 16                                                NaN   Daniel
# 17                                                NaN   Daniel
# 18                                                NaN   Daniel
# 19  3D Printer example is it derived from a model?...   Daniel
# 20  Mentioned all possible DT definitions... Uses ...   Daniel
# 21                                                NaN   Daniel
# 22                                                NaN   Daniel
# 23                                                NaN   Daniel
# 24                                           Topocity   Daniel
# 25                                                NaN   Daniel
# 26                                              MOMoT   Daniel
# 27                                                NaN   Daniel
# 28                                                NaN   Daniel
# 29                                                NaN   Daniel
# 30                                                NaN   Daniel
# 31                                                NaN   Daniel
# 32                             DT used for monitoring   Daniel
# 33           Math tranformations but nothing on model   Daniel
# 34                                                NaN   Daniel
# 35                                                NaN   Daniel
# 36                                                NaN   Daniel
# 37                                                NaN   Daniel
# 38                                                NaN   Daniel
# 39                                                NaN   Daniel
# 40                                                NaN   Daniel
# 41                                                NaN   Daniel
# 42                                                NaN   Daniel
# 43                                                NaN   Daniel
# 44                                                NaN   Daniel
# 45                                                NaN   Daniel
# 46                                                NaN   Daniel
# 47                                                NaN   Daniel
# 48                    models unknown, purpose unclear   Daniel
# 49                                                NaN   Daniel
# 50                                                NaN   Daniel
# 51                                                NaN   Daniel
# 52                                             WTF...   Daniel
# 53                                                NaN   Daniel
# 54                                                NaN   Daniel
# 55                                                NaN   Daniel
# 56  Extension of "Digital Twin of an Electrical Mo...   Daniel
# 57  transformation of electrical something to WHAT...   Daniel
# 58                                                NaN   Daniel

# %%
data_merged = pd.concat([data_jingxi, data_daniel, data_jerome, data_ann])
data_merged.shape
# Out:
# (231, 26)
